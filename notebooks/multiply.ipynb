# %%
def multiply(a,b):
    return(a*b)

# %%
multiply(3,4)
# Out:
# 12

# %%
multiply(5,8)
# Out:
# 40

# %%
def square(a,b,x):
    result = multiply(a,b)
    return result ** x

print(square(1,8,2))
# Out:
# 64
